# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
from torch.utils.data import DataLoader, Dataset
import torch
import pandas as pd
import re
from datasets import load_dataset, load_from_disk
from pathlib import Path
from dotenv import load_dotenv
load_dotenv()


device = torch.device("cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu")
print(device)
# Out:
# mps

# %%
# student model

student_tokenizer = AutoTokenizer.from_pretrained("google/gemma-2b-it")
student_model = AutoModelForCausalLM.from_pretrained(
    "google/gemma-2b-it",
    torch_dtype=torch.float16
).to(device)
# Out:
# `config.hidden_act` is ignored, you should use `config.hidden_activation` instead.
# Gemma's activation function will be set to `gelu_pytorch_tanh`. Please, use
# `config.hidden_activation` if you want to override this behaviour.
# See https://github.com/huggingface/transformers/pull/29402 for more details.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
student_tokenizer.add_special_tokens({"pad_token":"<pad>"})
student_model.generation_config.pad_token_id = student_tokenizer.pad_token_id

# %%
# Testing cell
inputs = student_tokenizer('The quadratic formula is', return_tensors="pt").to(device)



outputs = student_model.generate(**inputs, max_new_tokens=50, do_sample=False, truncate=True, eos_token_id=50256, ).to(device)
output_answer = student_tokenizer.batch_decode(outputs, skip_special_tokens=True)[0]
output_answer
# Out:
# 'The quadratic formula is a very useful tool for solving problems involving the quadratic equation. It is also used to solve problems involving the cubic equation.\n\nThe quadratic formula is a very useful tool for solving problems involving the quadratic equation. It is'

# %%
t = student_tokenizer('The quadratic formula is a very useful tool for solving problems involving the quadratic equation. It is also used to solve problems involving the cubic equation.\n\nThe quadratic formula is a very useful tool for solving problems involving the quadratic equation. It is also used to solve problems involving the cubic equation.\n\nThe quadratic formula is a very useful tool for solving problems involving the quadratic equation. It is also used to solve problems involving the cubic equation.\n\nThe quadratic formula is a very useful tool for solving problems involving the quadratic equation. It is also used to solve problems involving the cubic equation.\n\nThe quadratic formula is a very useful tool for solving problems involving the quadratic equation.', return_tensors="pt")
len(t['input_ids'][0].tolist())
# Out:
# 150

# %%
gsm8k = load_dataset("openai/gsm8k", "main")
gsm8k_test = gsm8k['test'].to_pandas()
gsm8k_train = gsm8k['train'].to_pandas()

# %%
def save_df(df : pd.DataFrame, model : str, dist_folder : str, edition : str):
    base_path = Path()
    base_path = base_path / '..' / 'logs' / model / dist_folder / f'{edition}.csv'
    df.to_csv(base_path)

def assess_model(df, model : str, dist_folder : str, subset : str, prompt_function, tokenizer, generator, max_tokens = 50, start = 0, end = None):
    numrows = df.shape[0]
    if not end:
        end = numrows
    i = 0
    df['model_answer'] = ''
    df['model_output_tokens'] = 0
    df['model_max_tokens'] = False
    for i, row in df[start:end].iterrows():
        tokens = tokenizer(row['question'])
        val, out_tokens = generator(tokens, max_tokens)
        out_token_count = len(out_tokens[0].tolist()) - len(tokens['input_ids'][0].tolist())
        df.loc[i, 'model_answer'] = val
        df.loc[i, 'model_output_tokens'] = out_token_count
        df.loc[i, 'model_max_tokens'] = True if out_token_count == max_tokens else False
        i += 1
        if i % 5 == 0:
            print(f'Completed : {i} out of {numrows}')
            print(f'Completed : {round(i/numrows, 4) * 100}%')
            print('\n')
        if i % 10 == 0:
            print(f'Completed : {i} out of {numrows}')
            save_df(df, model, dist_folder, f'intermediate_{i}')
    save_df(df, model, dist_folder, f'FINAL_Completed({start} : {end})')

# %%
def default_prompt(question):
    return question + '\n Please respond with just the answer. The answer is:'

# %%
def student_tokenizerd(prompt):
    tokens = student_tokenizer(prompt, return_tensors="pt").to(device)
    return tokens

# %%
def student_generation(tokens, max_tokens=50):
    outputs = student_model.generate(**tokens, max_new_tokens=max_tokens, do_sample=False).to(device)
    output_answer = student_tokenizer.batch_decode(outputs, skip_special_tokens=True)[0]
    return output_answer, outputs

# %%
hi, to = student_generation(student_tokenizerd(default_prompt(gsm8k_test['question'][6])), 50)

# %%
assess_model(gsm8k_test, 'gemma2b', 'no-distil-test', 'test', student_tokenizerd, student_generation, 300)
# Out:
# Completed : 5 out of 1319
# Completed : 0.38%
#
#
# Completed : 10 out of 1319
# Completed : 0.76%
#
#
# Completed : 10 out of 1319
# Completed : 15 out of 1319
# Completed : 1.1400000000000001%
#
#
# Completed : 20 out of 1319
# Completed : 1.52%
#
#
# Completed : 20 out of 1319
# Completed : 25 out of 1319
# Completed : 1.9%
#
#
# Completed : 30 out of 1319
# Completed : 2.27%
#
#
# Completed : 30 out of 1319
# Completed : 35 out of 1319
# Completed : 2.65%
#
#
# Completed : 40 out of 1319
# Completed : 3.0300000000000002%
#
#
# Completed : 40 out of 1319
# Completed : 45 out of 1319
# Completed : 3.4099999999999997%
#
#
# Completed : 50 out of 1319
# Completed : 3.7900000000000005%
#
#
# Completed : 50 out of 1319
# Completed : 55 out of 1319
# Completed : 4.17%
#
#
# Completed : 60 out of 1319
# Completed : 4.55%
#
#
# Completed : 60 out of 1319
# Completed : 65 out of 1319
# Completed : 4.93%
#
#
# Completed : 70 out of 1319
# Completed : 5.3100000000000005%
#
#
# Completed : 70 out of 1319
# Completed : 75 out of 1319
# Completed : 5.6899999999999995%
#
#
# Completed : 80 out of 1319
# Completed : 6.069999999999999%
#
#
# Completed : 80 out of 1319
# Completed : 85 out of 1319
# Completed : 6.4399999999999995%
#
#
# Completed : 90 out of 1319
# Completed : 6.819999999999999%
#
#
# Completed : 90 out of 1319
# Completed : 95 out of 1319
# Completed : 7.199999999999999%
#
#
# Completed : 100 out of 1319
# Completed : 7.580000000000001%
#
#
# Completed : 100 out of 1319
# Completed : 105 out of 1319
# Completed : 7.960000000000001%
#
#
# Completed : 110 out of 1319
# Completed : 8.34%
#
#
# Completed : 110 out of 1319
# Completed : 115 out of 1319
# Completed : 8.72%
#
#
# Completed : 120 out of 1319
# Completed : 9.1%
#
#
# Completed : 120 out of 1319
# Completed : 125 out of 1319
# Completed : 9.48%
#
#
# Completed : 130 out of 1319
# Completed : 9.86%
#
#
# Completed : 130 out of 1319
# Completed : 135 out of 1319
# Completed : 10.24%
#
#
# Completed : 140 out of 1319
# Completed : 10.61%
#
#
# Completed : 140 out of 1319
# Completed : 145 out of 1319
# Completed : 10.99%
#
#
# Completed : 150 out of 1319
# Completed : 11.37%
#
#
# Completed : 150 out of 1319
# Completed : 155 out of 1319
# Completed : 11.75%
#
#
# Completed : 160 out of 1319
# Completed : 12.13%
#
#
# Completed : 160 out of 1319
# Completed : 165 out of 1319
# Completed : 12.509999999999998%
#
#
# Completed : 170 out of 1319
# Completed : 12.889999999999999%
#
#
# Completed : 170 out of 1319
# Completed : 175 out of 1319
# Completed : 13.270000000000001%
#
#
# Completed : 180 out of 1319
# Completed : 13.65%
#
#
# Completed : 180 out of 1319
# Completed : 185 out of 1319
# Completed : 14.030000000000001%
#
#
# Completed : 190 out of 1319
# Completed : 14.399999999999999%
#
#
# Completed : 190 out of 1319
# Completed : 195 out of 1319
# Completed : 14.78%
#
#
# Completed : 200 out of 1319
# Completed : 15.160000000000002%
#
#
# Completed : 200 out of 1319
# Completed : 205 out of 1319
# Completed : 15.540000000000001%
#
#
# Completed : 210 out of 1319
# Completed : 15.920000000000002%
#
#
# Completed : 210 out of 1319
# Completed : 215 out of 1319
# Completed : 16.3%
#
#
# Completed : 220 out of 1319
# Completed : 16.68%
#
#
# Completed : 220 out of 1319
# Completed : 225 out of 1319
# Completed : 17.06%
#
#
# Completed : 230 out of 1319
# Completed : 17.44%
#
#
# Completed : 230 out of 1319
# Completed : 235 out of 1319
# Completed : 17.82%
#
#
# Completed : 240 out of 1319
# Completed : 18.2%
#
#
# Completed : 240 out of 1319
# Completed : 245 out of 1319
# Completed : 18.57%
#
#
# Completed : 250 out of 1319
# Completed : 18.95%
#
#
# Completed : 250 out of 1319
# Completed : 255 out of 1319
# Completed : 19.33%
#
#
# Completed : 260 out of 1319
# Completed : 19.71%
#
#
# Completed : 260 out of 1319
# Completed : 265 out of 1319
# Completed : 20.09%
#
#
# Completed : 270 out of 1319
# Completed : 20.47%
#
#
# Completed : 270 out of 1319
# Completed : 275 out of 1319
# Completed : 20.849999999999998%
#
#
# Completed : 280 out of 1319
# Completed : 21.23%
#
#
# Completed : 280 out of 1319
# Completed : 285 out of 1319
# Completed : 21.61%
#
#
# Completed : 290 out of 1319
# Completed : 21.990000000000002%
#
#
# Completed : 290 out of 1319
# Completed : 295 out of 1319
# Completed : 22.37%
#
#
# Completed : 300 out of 1319
# Completed : 22.74%
#
#
# Completed : 300 out of 1319
# Completed : 305 out of 1319
# Completed : 23.119999999999997%
#
#
# Completed : 310 out of 1319
# Completed : 23.5%
#
#
# Completed : 310 out of 1319
# Completed : 315 out of 1319
# Completed : 23.880000000000003%
#
#
# Completed : 320 out of 1319
# Completed : 24.26%
#
#
# Completed : 320 out of 1319
# Completed : 325 out of 1319
# Completed : 24.64%
#
#
# Completed : 330 out of 1319
# Completed : 25.019999999999996%
#
#
# Completed : 330 out of 1319
# Completed : 335 out of 1319
# Completed : 25.4%
#
#
# Completed : 340 out of 1319
# Completed : 25.779999999999998%
#
#
# Completed : 340 out of 1319
# Completed : 345 out of 1319
# Completed : 26.16%
#
#
# Completed : 350 out of 1319
# Completed : 26.540000000000003%
#
#
# Completed : 350 out of 1319
# Completed : 355 out of 1319
# Completed : 26.91%
#
#
# Completed : 360 out of 1319
# Completed : 27.29%
#
#
# Completed : 360 out of 1319
# Completed : 365 out of 1319
# Completed : 27.67%
#
#
# Completed : 370 out of 1319
# Completed : 28.050000000000004%
#
#
# Completed : 370 out of 1319
# Completed : 375 out of 1319
# Completed : 28.43%
#
#
# Completed : 380 out of 1319
# Completed : 28.810000000000002%
#
#
# Completed : 380 out of 1319
# Completed : 385 out of 1319
# Completed : 29.189999999999998%
#
#
# Completed : 390 out of 1319
# Completed : 29.57%
#
#
# Completed : 390 out of 1319
# Completed : 395 out of 1319
# Completed : 29.95%
#
#
# Completed : 400 out of 1319
# Completed : 30.330000000000002%
#
#
# Completed : 400 out of 1319
# Completed : 405 out of 1319
# Completed : 30.709999999999997%
#
#
# Completed : 410 out of 1319
# Completed : 31.080000000000002%
#
#
# Completed : 410 out of 1319
# Completed : 415 out of 1319
# Completed : 31.46%
#
#
# Completed : 420 out of 1319
# Completed : 31.840000000000003%
#
#
# Completed : 420 out of 1319
# Completed : 425 out of 1319
# Completed : 32.22%
#
#
# Completed : 430 out of 1319
# Completed : 32.6%
#
#
# Completed : 430 out of 1319
# Completed : 435 out of 1319
# Completed : 32.98%
#
#
# Completed : 440 out of 1319
# Completed : 33.36%
#
#
# Completed : 440 out of 1319
# Completed : 445 out of 1319
# Completed : 33.739999999999995%
#
#
# Completed : 450 out of 1319
# Completed : 34.12%
#
#
# Completed : 450 out of 1319
# Completed : 455 out of 1319
# Completed : 34.5%
#
#
# Completed : 460 out of 1319
# Completed : 34.870000000000005%
#
#
# Completed : 460 out of 1319
# Completed : 465 out of 1319
# Completed : 35.25%
#
#
# Completed : 470 out of 1319
# Completed : 35.63%
#
#
# Completed : 470 out of 1319
# Completed : 475 out of 1319
# Completed : 36.01%
#
#
# Completed : 480 out of 1319
# Completed : 36.39%
#
#
# Completed : 480 out of 1319
# Completed : 485 out of 1319
# Completed : 36.77%
#
#
# Completed : 490 out of 1319
# Completed : 37.15%
#
#
# Completed : 490 out of 1319
# Completed : 495 out of 1319
# Completed : 37.53%
#
#
# Completed : 500 out of 1319
# Completed : 37.91%
#
#
# Completed : 500 out of 1319
# Completed : 505 out of 1319
# Completed : 38.29%
#
#
# Completed : 510 out of 1319
# Completed : 38.67%
#
#
# Completed : 510 out of 1319
# Completed : 515 out of 1319
# Completed : 39.04%
#
#
# Completed : 520 out of 1319
# Completed : 39.42%
#
#
# Completed : 520 out of 1319
# Completed : 525 out of 1319
# Completed : 39.800000000000004%
#
#
# Completed : 530 out of 1319
# Completed : 40.18%
#
#
# Completed : 530 out of 1319
# Completed : 535 out of 1319
# Completed : 40.56%
#
#
# Completed : 540 out of 1319
# Completed : 40.94%
#
#
# Completed : 540 out of 1319
# Completed : 545 out of 1319
# Completed : 41.32%
#
#
# Completed : 550 out of 1319
# Completed : 41.699999999999996%
#
#
# Completed : 550 out of 1319
# Completed : 555 out of 1319
# Completed : 42.08%
#
#
# Completed : 560 out of 1319
# Completed : 42.46%
#
#
# Completed : 560 out of 1319
# Completed : 565 out of 1319
# Completed : 42.84%
#
#
# Completed : 570 out of 1319
# Completed : 43.21%
#
#
# Completed : 570 out of 1319
# Completed : 575 out of 1319
# Completed : 43.59%
#
#
# Completed : 580 out of 1319
# Completed : 43.97%
#
#
# Completed : 580 out of 1319
# Completed : 585 out of 1319
# Completed : 44.35%
#
#
# Completed : 590 out of 1319
# Completed : 44.73%
#
#
# Completed : 590 out of 1319
# Completed : 595 out of 1319
# Completed : 45.11%
#
#
# Completed : 600 out of 1319
# Completed : 45.49%
#
#
# Completed : 600 out of 1319
# Completed : 605 out of 1319
# Completed : 45.87%
#
#
# Completed : 610 out of 1319
# Completed : 46.25%
#
#
# Completed : 610 out of 1319
# Completed : 615 out of 1319
# Completed : 46.63%
#
#
# Completed : 620 out of 1319
# Completed : 47.010000000000005%
#
#
# Completed : 620 out of 1319
# Completed : 625 out of 1319
# Completed : 47.38%
#
#
# Completed : 630 out of 1319
# Completed : 47.760000000000005%
#
#
# Completed : 630 out of 1319
# Completed : 635 out of 1319
# Completed : 48.14%
#
#
# Completed : 640 out of 1319
# Completed : 48.52%
#
#
# Completed : 640 out of 1319
# Completed : 645 out of 1319
# Completed : 48.9%
#
#
# Completed : 650 out of 1319
# Completed : 49.28%
#
#
# Completed : 650 out of 1319
# Completed : 655 out of 1319
# Completed : 49.66%
#
#
# Completed : 660 out of 1319
# Completed : 50.03999999999999%
#
#
# Completed : 660 out of 1319
# Completed : 665 out of 1319
# Completed : 50.42%
#
#
# Completed : 670 out of 1319
# Completed : 50.8%
#
#
# Completed : 670 out of 1319
# Completed : 675 out of 1319
# Completed : 51.18000000000001%
#
#
# Completed : 680 out of 1319
# Completed : 51.55%
#
#
# Completed : 680 out of 1319
# Completed : 685 out of 1319
# Completed : 51.93%
#
#
# Completed : 690 out of 1319
# Completed : 52.31%
#
#
# Completed : 690 out of 1319
# Completed : 695 out of 1319
# Completed : 52.690000000000005%
#
#
# Completed : 700 out of 1319
# Completed : 53.06999999999999%
#
#
# Completed : 700 out of 1319
# Completed : 705 out of 1319
# Completed : 53.449999999999996%
#
#
# Completed : 710 out of 1319
# Completed : 53.83%
#
#
# Completed : 710 out of 1319
# Completed : 715 out of 1319
# Completed : 54.21%
#
#
# Completed : 720 out of 1319
# Completed : 54.59%
#
#
# Completed : 720 out of 1319
# Completed : 725 out of 1319
# Completed : 54.97%
#
#
# Completed : 730 out of 1319
# Completed : 55.34%
#
#
# Completed : 730 out of 1319
# Completed : 735 out of 1319
# Completed : 55.720000000000006%
#
#
# Completed : 740 out of 1319
# Completed : 56.10000000000001%
#
#
# Completed : 740 out of 1319
# Completed : 745 out of 1319
# Completed : 56.48%
#
#
# Completed : 750 out of 1319
# Completed : 56.86%
#
#
# Completed : 750 out of 1319
# Completed : 755 out of 1319
# Completed : 57.24%
#
#
# Completed : 760 out of 1319
# Completed : 57.620000000000005%
#
#
# Completed : 760 out of 1319
# Completed : 765 out of 1319
# Completed : 57.99999999999999%
#
#
# Completed : 770 out of 1319
# Completed : 58.379999999999995%
#
#
# Completed : 770 out of 1319
# Completed : 775 out of 1319
# Completed : 58.76%
#
#
# Completed : 780 out of 1319
# Completed : 59.14%
#
#
# Completed : 780 out of 1319
# Completed : 785 out of 1319
# Completed : 59.51%
#
#
# Completed : 790 out of 1319
# Completed : 59.89%
#
#
# Completed : 790 out of 1319
# Completed : 795 out of 1319
# Completed : 60.27%
#
#
# Completed : 800 out of 1319
# Completed : 60.650000000000006%
#
#
# Completed : 800 out of 1319
# Completed : 805 out of 1319
# Completed : 61.029999999999994%
#
#
# Completed : 810 out of 1319
# Completed : 61.41%
#
#
# Completed : 810 out of 1319
# Completed : 815 out of 1319
# Completed : 61.79%
#
#
# Completed : 820 out of 1319
# Completed : 62.17%
#
#
# Completed : 820 out of 1319
# Completed : 825 out of 1319
# Completed : 62.55%
#
#
# Completed : 830 out of 1319
# Completed : 62.93%
#
#
# Completed : 830 out of 1319
# Completed : 835 out of 1319
# Completed : 63.31%
#
#
# Completed : 840 out of 1319
# Completed : 63.68000000000001%
#
#
# Completed : 840 out of 1319
# Completed : 845 out of 1319
# Completed : 64.05999999999999%
#
#
# Completed : 850 out of 1319
# Completed : 64.44%
#
#
# Completed : 850 out of 1319
# Completed : 855 out of 1319
# Completed : 64.82%
#
#
# Completed : 860 out of 1319
# Completed : 65.2%
#
#
# Completed : 860 out of 1319
# Completed : 865 out of 1319
# Completed : 65.58%
#
#
# Completed : 870 out of 1319
# Completed : 65.96%
#
#
# Completed : 870 out of 1319
# Completed : 875 out of 1319
# Completed : 66.34%
#
#
# Completed : 880 out of 1319
# Completed : 66.72%
#
#
# Completed : 880 out of 1319
# Completed : 885 out of 1319
# Completed : 67.10000000000001%
#
#
# Completed : 890 out of 1319
# Completed : 67.47999999999999%
#
#
# Completed : 890 out of 1319
# Completed : 895 out of 1319
# Completed : 67.85%
#
#
# Completed : 900 out of 1319
# Completed : 68.23%
#
#
# Completed : 900 out of 1319
# Completed : 905 out of 1319
# Completed : 68.61%
#
#
# Completed : 910 out of 1319
# Completed : 68.99%
#
#
# Completed : 910 out of 1319
# Completed : 915 out of 1319
# Completed : 69.37%
#
#
# Completed : 920 out of 1319
# Completed : 69.75%
#
#
# Completed : 920 out of 1319
# Completed : 925 out of 1319
# Completed : 70.13000000000001%
#
#
# Completed : 930 out of 1319
# Completed : 70.50999999999999%
#
#
# Completed : 930 out of 1319
# Completed : 935 out of 1319
# Completed : 70.89%
#
#
# Completed : 940 out of 1319
# Completed : 71.27%
#
#
# Completed : 940 out of 1319
# Completed : 945 out of 1319
# Completed : 71.65%
#
#
# Completed : 950 out of 1319
# Completed : 72.02%
#
#
# Completed : 950 out of 1319
# Completed : 955 out of 1319
# Completed : 72.39999999999999%
#
#
# Completed : 960 out of 1319
# Completed : 72.78%
#
#
# Completed : 960 out of 1319
# Completed : 965 out of 1319
# Completed : 73.16%
#
#
# Completed : 970 out of 1319
# Completed : 73.54%
#
#
# Completed : 970 out of 1319
# Completed : 975 out of 1319
# Completed : 73.92%
#
#
# Completed : 980 out of 1319
# Completed : 74.3%
#
#
# Completed : 980 out of 1319
# Completed : 985 out of 1319
# Completed : 74.68%
#
#
# Completed : 990 out of 1319
# Completed : 75.06%
#
#
# Completed : 990 out of 1319
# Completed : 995 out of 1319
# Completed : 75.44%
#
#
# Completed : 1000 out of 1319
# Completed : 75.82%
#
#
# Completed : 1000 out of 1319
# Completed : 1005 out of 1319
# Completed : 76.19%
#
#
# Completed : 1010 out of 1319
# Completed : 76.57000000000001%
#
#
# Completed : 1010 out of 1319
# Completed : 1015 out of 1319
# Completed : 76.95%
#
#
# Completed : 1020 out of 1319
# Completed : 77.33%
#
#
# Completed : 1020 out of 1319
# Completed : 1025 out of 1319
# Completed : 77.71000000000001%
#
#
# Completed : 1030 out of 1319
# Completed : 78.09%
#
#
# Completed : 1030 out of 1319
# Completed : 1035 out of 1319
# Completed : 78.47%
#
#
# Completed : 1040 out of 1319
# Completed : 78.85%
#
#
# Completed : 1040 out of 1319
# Completed : 1045 out of 1319
# Completed : 79.23%
#
#
# Completed : 1050 out of 1319
# Completed : 79.61%
#
#
# Completed : 1050 out of 1319
# Completed : 1055 out of 1319
# Completed : 79.97999999999999%
#
#
# Completed : 1060 out of 1319
# Completed : 80.36%
#
#
# Completed : 1060 out of 1319
# Completed : 1065 out of 1319
# Completed : 80.74%
#
#
# Completed : 1070 out of 1319
# Completed : 81.12%
#
#
# Completed : 1070 out of 1319
# Completed : 1075 out of 1319
# Completed : 81.5%
#
#
# Completed : 1080 out of 1319
# Completed : 81.88%
#
#
# Completed : 1080 out of 1319
# Completed : 1085 out of 1319
# Completed : 82.26%
#
#
# Completed : 1090 out of 1319
# Completed : 82.64%
#
#
# Completed : 1090 out of 1319
# Completed : 1095 out of 1319
# Completed : 83.02000000000001%
#
#
# Completed : 1100 out of 1319
# Completed : 83.39999999999999%
#
#
# Completed : 1100 out of 1319
# Completed : 1105 out of 1319
# Completed : 83.78%
#
#
# Completed : 1110 out of 1319
# Completed : 84.15%
#
#
# Completed : 1110 out of 1319
# Completed : 1115 out of 1319
# Completed : 84.53%
#
#
# Completed : 1120 out of 1319
# Completed : 84.91%
#
#
# Completed : 1120 out of 1319
# Completed : 1125 out of 1319
# Completed : 85.28999999999999%
#
#
# Completed : 1130 out of 1319
# Completed : 85.67%
#
#
# Completed : 1130 out of 1319
# Completed : 1135 out of 1319
# Completed : 86.05000000000001%
#
#
# Completed : 1140 out of 1319
# Completed : 86.42999999999999%
#
#
# Completed : 1140 out of 1319
# Completed : 1145 out of 1319
# Completed : 86.81%
#
#
# Completed : 1150 out of 1319
# Completed : 87.19%
#
#
# Completed : 1150 out of 1319
# Completed : 1155 out of 1319
# Completed : 87.57000000000001%
#
#
# Completed : 1160 out of 1319
# Completed : 87.94999999999999%
#
#
# Completed : 1160 out of 1319
# Completed : 1165 out of 1319
# Completed : 88.32%
#
#
# Completed : 1170 out of 1319
# Completed : 88.7%
#
#
# Completed : 1170 out of 1319
# Completed : 1175 out of 1319
# Completed : 89.08%
#
#
# Completed : 1180 out of 1319
# Completed : 89.46%
#
#
# Completed : 1180 out of 1319
# Completed : 1185 out of 1319
# Completed : 89.84%
#
#
# Completed : 1190 out of 1319
# Completed : 90.22%
#
#
# Completed : 1190 out of 1319
# Completed : 1195 out of 1319
# Completed : 90.60000000000001%
#
#
# Completed : 1200 out of 1319
# Completed : 90.98%
#
#
# Completed : 1200 out of 1319
# Completed : 1205 out of 1319
# Completed : 91.36%
#
#
# Completed : 1210 out of 1319
# Completed : 91.74%
#
#
# Completed : 1210 out of 1319
# Completed : 1215 out of 1319
# Completed : 92.12%
#
#
# Completed : 1220 out of 1319
# Completed : 92.49000000000001%
#
#
# Completed : 1220 out of 1319
# Completed : 1225 out of 1319
# Completed : 92.86999999999999%
#
#
# Completed : 1230 out of 1319
# Completed : 93.25%
#
#
# Completed : 1230 out of 1319
# Completed : 1235 out of 1319
# Completed : 93.63%
#
#
# Completed : 1240 out of 1319
# Completed : 94.01%
#
#
# Completed : 1240 out of 1319
# Completed : 1245 out of 1319
# Completed : 94.39%
#
#
# Completed : 1250 out of 1319
# Completed : 94.77%
#
#
# Completed : 1250 out of 1319
# Completed : 1255 out of 1319
# Completed : 95.15%
#
#
# Completed : 1260 out of 1319
# Completed : 95.53%
#
#
# Completed : 1260 out of 1319
# Completed : 1265 out of 1319
# Completed : 95.91%
#
#
# Completed : 1270 out of 1319
# Completed : 96.28999999999999%
#
#
# Completed : 1270 out of 1319
# Completed : 1275 out of 1319
# Completed : 96.66%
#
#
# Completed : 1280 out of 1319
# Completed : 97.04%
#
#
# Completed : 1280 out of 1319
# Completed : 1285 out of 1319
# Completed : 97.42%
#
#
# Completed : 1290 out of 1319
# Completed : 97.8%
#
#
# Completed : 1290 out of 1319
# Completed : 1295 out of 1319
# Completed : 98.18%
#
#
# Completed : 1300 out of 1319
# Completed : 98.56%
#
#
# Completed : 1300 out of 1319
# Completed : 1305 out of 1319
# Completed : 98.94%
#
#
# Completed : 1310 out of 1319
# Completed : 99.32%
#
#
# Completed : 1310 out of 1319
# Completed : 1315 out of 1319
# Completed : 99.7%

# %% [markdown]
# # Load data

# %%
def load_disk(model : str, dist_folder : str, edition : str = 'FINAL'):
    base_path = Path()
    base_path = base_path / '..' / 'logs' / model / dist_folder / edition
    return load_from_disk(base_path)

# %%
gsm8k_data = load_disk('gpt2-xl', 'no-distil-test', 'intermediate_5')

# %%
gsm8k_data['test']
# Out:
# Dataset({
#     features: ['question', 'answer'],
#     num_rows: 1319
# })
